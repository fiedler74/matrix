# %%
from google.colabe import drive
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-1260b860d4c1> in <module>()
# ----> 1 from google.colabe import drive
#
# ModuleNotFoundError: No module named 'google.colabe'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from google.colab import drive

# %%
import pandas as pd

# %%
import numpy as np

# %%
# !pip install datadotworld
# !pip install datadotworld(pandas)
# Out:
# ...
#      |████████████████████████████████| 163kB 2.9MB/s
# ...
#      |████████████████████████████████| 71kB 5.9MB/s
# ...
#      |████████████████████████████████| 71kB 5.7MB/s
# ...
#      |████████████████████████████████| 71kB 5.3MB/s
# ...
#      |████████████████████████████████| 92kB 6.6MB/s
# ...
#      |████████████████████████████████| 174kB 9.2MB/s
# ...
#      |████████████████████████████████| 245kB 9.5MB/s
# ...
#      |████████████████████████████████| 71kB 6.8MB/s
# ...
#      |████████████████████████████████| 51kB 6.3MB/s
# ...
#   Created wheel for linear-tsv: filename=linear_tsv-1.1.0-cp36-none-any.whl size=7383 sha256=c59cf1df0340966ba3359441252629c891c0fa0491e9e07dcb5bbc3737b3e534
#   Stored in directory: /root/.cache/pip/wheels/3f/8a/cb/38917fd1ef4356b9870ace7331b83417dc594bf2c029bd991f
# ...
#   Created wheel for openpyxl: filename=openpyxl-3.0.3-py2.py3-none-any.whl size=241262 sha256=f69c4557c48f3b93453b673e0530fe6daebfddace34ba613ab2708874ed05dba
# ...

# %%
# !dw configure
# Out:
# API token (obtained at: https://data.world/settings/advanced): eyJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJwcm9kLXVzZXItY2xpZW50OmZpZWRsZXIiLCJpc3MiOiJhZ2VudDpmaWVkbGVyOjowY2IwZGQ5MC03ZDI4LTQyOTktODJiMS0yYzlkNjRlNjU5MDEiLCJpYXQiOjE1ODE1NDYwODcsInJvbGUiOlsidXNlcl9hcGlfcmVhZCIsInVzZXJfYXBpX3dyaXRlIl0sImdlbmVyYWwtcHVycG9zZSI6dHJ1ZSwic2FtbCI6e319.0niXdj26YMusKAypcakOGDO0UTtnv1kn5P92auaBGKEImzHt92R4Zrjpyco2bTufcZaIvsG-zfh2SVv77-3bvA

# %%
import datadotworld as dw

# %%
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
ls
# Out:
# drive/  sample_data/

# %%
cd "drive/My drive/Colab Notebooks/matrix"
# Out:
# [Errno 2] No such file or directory: 'drive/My drive/Colab Notebooks/matrix'
# /content

# %%
cd drive/
# Out:
# /content/drive

# %%
ls
# Out:
# 'My Drive'/

# %%
cd "My Drive"
# Out:
# /content/drive/My Drive

# %%
ls
# Out:
#  20150524KRAKOW/
#  20160917_200155.jpg
#  20180122_202917.jpg
#  Arkadiusz_Skrzypek-styczeń.gsheet
#  Artur.gsheet
#  Brian.Lopes_Lee.McCormack-Mastering.Mountain.Bike.Skills.2nd.Edition.PDF-Jahguide.pdf
# 'Colab Notebooks'/
# 'Dokument bez tytułu (1).gdoc'
# 'Dokument bez tytułu.gdoc'
#  Dokumenty/
# 'Dom_3-instalacja ogrzewanie podlogowe (8).JPG'
# 'EDUKACJI LOGO 400.png'
# 'Faktura2019 03 228819 SP 2.pdf'
# 'Faktura dla klientów pl rozliczana w EUR.pdf'
# 'Faktury_ostatnie zmiany_poprawki.gdoc'
#  FVK047.pdf
#  image003.png
#  img/
#  IMG_0813.JPG
#  KMC.gsheet
#  Kostka.gsheet
# 'Koszty stałe.gsheet'
# 'listy startowe - czasówka1 (1).pdf'
#  ŁS/
#  MY_MOBI/
# 'Oświadczenie (1).gdoc'
#  Oświadczenie.gdoc
#  PlanFit.gsheet
#  Remont.gsheet
# 'Rower Peak 29.gsheet'
#  Sieborowice/
# 'Skrzypek Małgorzata.jpg'
#  Śpiewniki/
# 'Tomasz Skrzypek vpn NSG'/
# 'UPO PIT-37 Skrzypek Tomasz.pdf'
#  WEZWANIE_26_072018.pdf
#  ZBI/

# %%
cd "Colab Notebooks/matrix"
# Out:
# /content/drive/My Drive/Colab Notebooks/matrix

# %%
ls
# Out:
# HelloGitHub.ipynb  LICENSE  matrix_one/  README.md

# %%
  # !mkdir data

# %%
# !echo 'data' > .gitignore

# %%
# !git add .gitignore

# %%
data = dw.load_dataset('datafiniti/mens-shoe-prices')

# %%
data
# Out:
# LocalDataset('/root/.dw/cache/datafiniti/mens-shoe-prices/latest/datapackage.json')

# %%
df = data.dataframes

# %%
data.dataframes
# Out:
# LazyLoadedDict({'7004_1': LazyLoadedValue(<pandas.DataFrame>)})

# %%
df = data.dataframes['7004_1']
# Out:
# /usr/local/lib/python3.6/dist-packages/datadotworld/models/dataset.py:209: UserWarning: Unable to set data frame dtypes automatically using 7004_1 schema. Data types may need to be adjusted manually. Error: Integer column has NA values in column 10
#   'Error: {}'.format(resource_name, e))
# /usr/local/lib/python3.6/dist-packages/datadotworld/util.py:121: DtypeWarning: Columns (39,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   return self._loader_func()

# %%
df.shape
# Out:
# (19387, 48)

# %%
df.sample(10)
# Out:
#                          id                  asins  ... websiteids   weight
# 5668   AVpfVHb8ilAPnD_xZwpn                    NaN  ...        NaN      NaN
# 11299  AVpff7zK1cnluZ0-l0ZF                    NaN  ...        NaN      NaN
# 3221   AVpfDyI51cnluZ0-c_q7                    NaN  ...        NaN      NaN
# 5102   AVpfF6PP1cnluZ0-dvkp                    NaN  ...        NaN  6.5 lbs
# 14011  AVpfzQAr1cnluZ0-rhik  B0083RNXHE,B007PYB67K  ...        NaN      NaN
# 6321   AVpe4pAb1cnluZ0-ZAF6                    NaN  ...        NaN      NaN
# 11017  AVpfKSoNilAPnD_xWPfF                    NaN  ...        NaN      NaN
# 2638   AVpe-eTwLJeJML43zn2f                    NaN  ...        NaN      NaN
# 1756   AVpfG5oF1cnluZ0-eEsV                    NaN  ...        NaN      NaN
# 14431  AVpf3x-d1cnluZ0-syKa                    NaN  ...        NaN      NaN
#
# [10 rows x 48 columns]

# %%
df_usd = df[df.prices_currency == 'USD'].copy()

# %%
df_usd['prices_amountmin'] = df_usd.prices_amountmin.astype(np.float)

# %%
df_usd['prices_amountmin'].hist()

# %%
filter_max = np.percentile(df_usd['prices_amountmin'],99)

# %%
df_usd_filter = df_usd[df_usd['prices_amountmin'] < filter_max]

# %%
df_usd_filter
# Out:
#                          id asins                brand  ...  vin websiteids  weight
# 0      AVpfHrJ6ilAPnD_xVXOI   NaN                Josmo  ...  NaN        NaN     NaN
# 1      AVpfHrJ6ilAPnD_xVXOI   NaN                Josmo  ...  NaN        NaN     NaN
# 2      AVpfHsWP1cnluZ0-eVZ7   NaN  SERVUS BY HONEYWELL  ...  NaN        NaN     NaN
# 3      AVpfHsWP1cnluZ0-eVZ7   NaN  SERVUS BY HONEYWELL  ...  NaN        NaN     NaN
# 4      AVpfHsWP1cnluZ0-eVZ7   NaN  SERVUS BY HONEYWELL  ...  NaN        NaN     NaN
# ...                     ...   ...                  ...  ...  ...        ...     ...
# 19382  AVpfdSjlilAPnD_xcGPm   NaN           Xray, XRay  ...  NaN        NaN     NaN
# 19383  AVpf3bFWilAPnD_xjrQ2   NaN                 Fila  ...  NaN        NaN     NaN
# 19384  AVpf0fJXLJeJML43EVe9   NaN          Seek Optics  ...  NaN        NaN     NaN
# 19385  AVpf0fJXLJeJML43EVe9   NaN          Seek Optics  ...  NaN        NaN     NaN
# ...

# %%
df_usd_filter.prices_amountmin.hist()

# %%
df_usd_filter.prices_amountmin.hist(bins=100)

# %%
df.to_csv('data/shose_price.csv', index=False)

# %%
ls
# Out:
# data/  HelloGitHub.ipynb  LICENSE  matrix_one/  README.md

# %%
# !cd matrix_one

# %%
ls
# Out:
# data/  HelloGitHub.ipynb  LICENSE  matrix_one/  README.md

# %%
# !git add matrix_one/day3.ipynb
# Out:
# fatal: pathspec 'matrix_one/day3.ipynb' did not match any files
